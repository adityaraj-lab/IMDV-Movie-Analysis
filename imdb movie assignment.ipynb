# %%
# in this dataset we have a list of top 100  imdb movie

# %%
# Importing the required librarie for this dataset
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
#first we will read the csv file by using read csv 
movie=pd.read_csv('dataset/Movie+Assignment+Data.csv')
movie.head()
# Out:
#                    Title  title_year     budget      Gross      actor_1_name  \
# 0             La La Land        2016   30000000  151101803      Ryan Gosling
# 1               Zootopia        2016  150000000  341268248  Ginnifer Goodwin
# 2                   Lion        2016   12000000   51738905         Dev Patel
# 3                Arrival        2016   47000000  100546139         Amy Adams
# 4  Manchester by the Sea        2016    9000000   47695371     Casey Affleck
#
#          actor_2_name     actor_3_name  actor_1_facebook_likes  \
# 0          Emma Stone       Amiée Conn                   14000
# 1       Jason Bateman       Idris Elba                    2800
# 2       Nicole Kidman      Rooney Mara                   33000
# 3       Jeremy Renner  Forest Whitaker                   35000
# 4  Michelle Williams     Kyle Chandler                     518
#
#    actor_2_facebook_likes  actor_3_facebook_likes  ...  Votes3044M Votes3044F  \
# ...

# %%
#now i am going to look how much rows nd columns we hvae in this data set
movie.shape
# Out:
# (100, 62)

# %%
#now we will check that is there any misssing values in our dataset
movie.isnull().sum().sum()
# Out:
# 37

# %%
#Check the column-wise info of the dataframe
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 62 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Title                   100 non-null    object
#  1   title_year              100 non-null    int64
#  2   budget                  100 non-null    int64
#  3   Gross                   100 non-null    int64
#  4   actor_1_name            100 non-null    object
#  5   actor_2_name            100 non-null    object
#  6   actor_3_name            100 non-null    object
#  7   actor_1_facebook_likes  100 non-null    int64
#  8   actor_2_facebook_likes  99 non-null     float64
#  9   actor_3_facebook_likes  98 non-null     float64
#  10  IMDb_rating             100 non-null    float64
#  11  genre_1                 100 non-null    object
#  12  genre_2                 97 non-null     object
#  13  genre_3                 74 non-null     object
# ...

# %%
#now we will see in which year most number of movie has been realised
sns.countplot(x='title_year',data=movie)
#now we can clearly see that most number of movie has been realised in 2014
# Out:
# <AxesSubplot:xlabel='title_year', ylabel='count'>

# %%
#now we will check that is there any misssing values in our dataset
movie.isnull().sum().sum()
#we can clearly see that there is no missing values in our dataset
# Out:
# 37

# %%
# now i am going to check all the discription about all columns 
movie.describe()
# Out:
#         title_year        budget         Gross  actor_1_facebook_likes  \
# count   100.000000  1.000000e+02  1.000000e+02              100.000000
# mean   2012.820000  7.838400e+07  1.468679e+08            13407.270000
# std       1.919491  7.445295e+07  1.454004e+08            10649.037862
# min    2010.000000  3.000000e+06  2.238380e+05               39.000000
# 25%    2011.000000  1.575000e+07  4.199752e+07             1000.000000
# 50%    2013.000000  4.225000e+07  1.070266e+08            13000.000000
# 75%    2014.000000  1.500000e+08  2.107548e+08            20000.000000
# max    2016.000000  2.600000e+08  9.366622e+08            35000.000000
#
#        actor_2_facebook_likes  actor_3_facebook_likes  IMDb_rating  \
# count               99.000000               98.000000   100.000000
# mean              7377.303030             3002.153061     7.883000
# std              13471.568216             6940.301133     0.247433
# ...

# %%
# Divide the 'gross' and 'budget' columns by 1000000 to convert '$' to 'million $'
movie['budget']=movie['budget']/1000000
movie['Gross']=movie['Gross']/1000000
movie.head()
# Out:
#                    Title  title_year  budget       Gross      actor_1_name  \
# 0             La La Land        2016    30.0  151.101803      Ryan Gosling
# 1               Zootopia        2016   150.0  341.268248  Ginnifer Goodwin
# 2                   Lion        2016    12.0   51.738905         Dev Patel
# 3                Arrival        2016    47.0  100.546139         Amy Adams
# 4  Manchester by the Sea        2016     9.0   47.695371     Casey Affleck
#
#          actor_2_name     actor_3_name  actor_1_facebook_likes  \
# 0          Emma Stone       Amiée Conn                   14000
# 1       Jason Bateman       Idris Elba                    2800
# 2       Nicole Kidman      Rooney Mara                   33000
# 3       Jeremy Renner  Forest Whitaker                   35000
# 4  Michelle Williams     Kyle Chandler                     518
#
#    actor_2_facebook_likes  actor_3_facebook_likes  ...  Votes3044M Votes3044F  \
# ...

# %%
# creating a new columns called profit 
movie["Profit"]= movie['Gross']-movie['budget'] 
movie.head()
# Out:
#                    Title  title_year  budget       Gross      actor_1_name  \
# 0             La La Land        2016    30.0  151.101803      Ryan Gosling
# 1               Zootopia        2016   150.0  341.268248  Ginnifer Goodwin
# 2                   Lion        2016    12.0   51.738905         Dev Patel
# 3                Arrival        2016    47.0  100.546139         Amy Adams
# 4  Manchester by the Sea        2016     9.0   47.695371     Casey Affleck
#
#          actor_2_name     actor_3_name  actor_1_facebook_likes  \
# 0          Emma Stone       Amiée Conn                   14000
# 1       Jason Bateman       Idris Elba                    2800
# 2       Nicole Kidman      Rooney Mara                   33000
# 3       Jeremy Renner  Forest Whitaker                   35000
# 4  Michelle Williams     Kyle Chandler                     518
#
#    actor_2_facebook_likes  actor_3_facebook_likes  ...  Votes3044F Votes45A  \
# ...

# %%
#now i want top 10 profitable movie list
movies=movie.sort_values(by='Profit',ascending=False)
df1=movies.head(10)
df1
# Out:
#                                          Title  title_year  budget  \
# 97  Star Wars: Episode VII - The Force Awakens        2015   245.0
# 11                                The Avengers        2012   220.0
# 47                                    Deadpool        2016    58.0
# 32             The Hunger Games: Catching Fire        2013   130.0
# 12                                 Toy Story 3        2010   200.0
# 8                        The Dark Knight Rises        2012   250.0
# 45                              The Lego Movie        2014    60.0
# 1                                     Zootopia        2016   150.0
# 41                               Despicable Me        2010    69.0
# 18                                  Inside Out        2015   175.0
#
#          Gross       actor_1_name       actor_2_name           actor_3_name  \
# 97  936.662225        Doug Walker         Rob Walker                      0
# ...

# %%
#now we will see the to 10 movies which have earn more profit
ax=sns.catplot(x='Title',y='Profit',kind='bar',data=df1)
ax.set_xticklabels(rotation=90)
#by this graph we can clearly see which movie has earn more profit

# %%
#now we want to see those movie which have gain -ve rofit on box office
df2=movie[movie['Profit']<0]
df3=df2.sort_values(by='Profit',ascending=True)
df3
# Out:
#                           Title  title_year  budget       Gross  \
# 22                         Hugo        2011   170.0   73.820094
# 39            The Little Prince        2015    81.2    1.339152
# 17             Edge of Tomorrow        2014   178.0  100.189501
# 7                       Tangled        2010   260.0  200.807262
# 46  Scott Pilgrim vs. the World        2010    60.0   31.494270
# 28           X-Men: First Class        2011   160.0  146.405371
# 82                      Flipped        2010    14.0    1.752214
# 66                      Warrior        2011    25.0   13.651662
# 56                         Rush        2013    38.0   26.903709
# 89                        Amour        2012     8.9    0.225377
# 99      Tucker and Dale vs Evil        2010     5.0    0.223838
#
#            actor_1_name        actor_2_name            actor_3_name  \
# 22  ChloÃ« Grace Moretz     Christopher Lee            Ray Winstone
# ...

# %%
#here is the list of all those movie which have earn -ve profit on boxoffice
df3.iloc[:,[0,62]]
# Out:
#                           Title     Profit
# 22                         Hugo -96.179906
# 39            The Little Prince -79.860848
# 17             Edge of Tomorrow -77.810499
# 7                       Tangled -59.192738
# 46  Scott Pilgrim vs. the World -28.505730
# 28           X-Men: First Class -13.594629
# 82                      Flipped -12.247786
# 66                      Warrior -11.348338
# 56                         Rush -11.096291
# 89                        Amour  -8.674623
# 99      Tucker and Dale vs Evil  -4.776162

# %%
#now i am going to plot all those movie which earn -ve profit
ax=sns.catplot(x='Title',y='Profit',kind='bar',data=df3)
ax.set_xticklabels(rotation=90)

# %%
#now we want to see that is movies profit depends on movies budget
sns.relplot(x='budget',y='Profit',kind='scatter',data=movie)
#now we can clearly see that there is no direct relation bw movies budget nd profit

# %%
movie['Total_faceboook_likes']=movie['actor_1_facebook_likes']+movie['actor_2_facebook_likes']+movie['actor_3_facebook_likes']
movie.sort_values(by='Total_faceboook_likes',ascending=False)
# Out:
#                                          Title  title_year  budget  \
# 2                                         Lion        2016    12.0
# 27                                   Inception        2010   160.0
# 14                  X-Men: Days of Future Past        2014   200.0
# 4                        Manchester by the Sea        2016     9.0
# 8                        The Dark Knight Rises        2012   250.0
# ..                                         ...         ...     ...
# 97  Star Wars: Episode VII - The Force Awakens        2015   245.0
# 34                                     Gravity        2013   100.0
# 0                                   La La Land        2016    30.0
# 3                                      Arrival        2016    47.0
# 6                               Doctor Strange        2016   165.0
#
#          Gross          actor_1_name        actor_2_name  \
# 2    51.738905             Dev Patel       Nicole Kidman
# ...

# %%
sns.relplot(x='Profit',y='Total_faceboook_likes',kind='scatter',data=movie)

# %%
#divide MetaCritic/10']
movie['MetaCritic']=movie['MetaCritic']/10

# %%
#creating a column in dataset called avg_rating
#avg_rating=imdb_rating+'MetaCritic_rating
movie['avg_rating']=(movie['MetaCritic']+movie['IMDb_rating'])/2
movie.loc[:,['Title','IMDb_rating','MetaCritic','avg_rating','Profit']]
# Out:
#                                            Title  IMDb_rating  MetaCritic  \
# 0                                     La La Land          8.2         9.3
# 1                                       Zootopia          8.1         7.8
# 2                                           Lion          8.1         6.9
# 3                                        Arrival          8.0         8.1
# 4                          Manchester by the Sea          7.9         9.6
# ..                                           ...          ...         ...
# 95                                      Whiplash          8.5         8.8
# 96                               Before Midnight          7.9         9.4
# 97    Star Wars: Episode VII - The Force Awakens          8.1         8.1
# 98  Harry Potter and the Deathly Hallows: Part I          7.7         6.5
# 99                       Tucker and Dale vs Evil          7.6         6.5
#
#     avg_rating      Profit
# 0         8.75  121.101803
# ...

# %%
df4=movie.sort_values(by='Profit',ascending=True)
df5=df4.loc[:,['Title','IMDb_rating','MetaCritic','avg_rating','Profit','content_rating']]
df5.head(11)
# Out:
#                           Title  IMDb_rating  MetaCritic  avg_rating  \
# 22                         Hugo          7.5         8.3        7.90
# 39            The Little Prince          7.8         7.0        7.40
# 17             Edge of Tomorrow          7.9         7.1        7.50
# 7                       Tangled          7.8         7.1        7.45
# 46  Scott Pilgrim vs. the World          7.5         6.9        7.20
# 28           X-Men: First Class          7.8         6.5        7.15
# 82                      Flipped          7.7         NaN         NaN
# 66                      Warrior          8.2         7.1        7.65
# 56                         Rush          8.1         7.5        7.80
# 89                        Amour          7.9         9.4        8.65
# 99      Tucker and Dale vs Evil          7.6         6.5        7.05
#
#        Profit content_rating
# 22 -96.179906             PG
# 39 -79.860848             PG
# 17 -77.810499          PG-13
# ...

# %%
df6=movie.sort_values(by='Profit',ascending=False)
df7=df6.loc[:,['Title','IMDb_rating','MetaCritic','avg_rating','Profit']]
df7.head(20)
# Out:
#                                            Title  IMDb_rating  MetaCritic  \
# 97    Star Wars: Episode VII - The Force Awakens          8.1         8.1
# 11                                  The Avengers          8.1         6.9
# 47                                      Deadpool          8.0         6.5
# 32               The Hunger Games: Catching Fire          7.6         7.6
# 12                                   Toy Story 3          8.3         9.2
# 8                          The Dark Knight Rises          8.4         7.8
# 45                                The Lego Movie          7.8         8.3
# 1                                       Zootopia          8.1         7.8
# 41                                 Despicable Me          7.7         7.2
# 18                                    Inside Out          8.2         9.4
# 34                                       Gravity          7.8         9.6
# 19                       Guardians of the Galaxy          8.1         7.6
# ...

# %%
df6[['Title','Country','Profit','content_rating']].head(20)
# Out:
#                                            Title    Country      Profit  \
# 97    Star Wars: Episode VII - The Force Awakens        USA  691.662225
# 11                                  The Avengers        USA  403.279547
# 47                                      Deadpool        USA  305.024263
# 32               The Hunger Games: Catching Fire        USA  294.645577
# 12                                   Toy Story 3        USA  214.984497
# 8                          The Dark Knight Rises        USA  198.130642
# 45                                The Lego Movie  Australia  197.756197
# 1                                       Zootopia        USA  191.268248
# 41                                 Despicable Me        USA  182.501645
# 18                                    Inside Out        USA  181.454367
# 34                                       Gravity         UK  174.084951
# 19                       Guardians of the Galaxy        USA  163.130696
# ...

# %%
sns.catplot(x='content_rating',y='Profit',kind='bar',data=movie)

# %%
sns.relplot(x='avg_rating',y='Profit',kind='scatter',col='content_rating',data=movie,col_wrap=2)

# %%
sns.catplot(x='IMDb_rating',y='Profit',kind='violin',col='content_rating',data=movie,col_wrap=2)

# %%
df=movie.loc[:,['Title','content_rating','CVotesU18M']]
df1=df[df['content_rating']=='R']
df1.sort_values(by='CVotesU18M',ascending=False).head(10)
# Out:
#                                               Title content_rating  CVotesU18M
# 47                                         Deadpool              R        3601
# 36                          The Wolf of Wall Street              R        2842
# 35                                 Django Unchained              R        2726
# 29                               Mad Max: Fury Road              R        2682
# 95                                         Whiplash              R        2200
# 31                                     The Revenant              R        2141
# 40                                   Shutter Island              R        1811
# 43                                        Gone Girl              R        1598
# 72  Birdman or (The Unexpected Virtue of Ignorance)              R        1538
# 65                         The Grand Budapest Hotel              R        1537

# %%
df=movie.loc[:,['Title','content_rating','CVotesU18F']]
df1=df[df['content_rating']=='R']
df1.sort_values(by='CVotesU18F',ascending=False).head(10)
# Out:
#                        Title content_rating  CVotesU18F
# 47                  Deadpool              R         969
# 36   The Wolf of Wall Street              R         757
# 43                 Gone Girl              R         665
# 68   Silver Linings Playbook              R         660
# 95                  Whiplash              R         660
# 65  The Grand Budapest Hotel              R         530
# 83                Black Swan              R         516
# 35          Django Unchained              R         501
# 40            Shutter Island              R         494
# 31              The Revenant              R         458

# %%
#run time analysis 
sns.histplot(x='Runtime',data=movie)
# Out:
# <AxesSubplot:xlabel='Runtime', ylabel='Count'>

# %%
df_by_genre=movies.loc[:,"CVotes10":"VotesnUS"]
df_by_genre[["genre_1","genre_2","genre_3"]]=movies[["genre_1","genre_2","genre_3"]]
df_by_genre
# Out:
#     CVotes10  CVotes09  CVotes08  CVotes07  CVotes06  CVotes05  CVotes04  \
# 97    155391    161810    166378     99402     40734     18060      8751
# 11    260257    234203    264290    162604     67579     27957     12176
# 47    147467    147966    170810    105717     41811     15510      7046
# 32     85219     83874    150153    121748     50575     18571      7591
# 12    139773    149992    158704     88289     31291     11850      4859
# ..       ...       ...       ...       ...       ...       ...       ...
# 46     47292     48976     79198     59689     28452     13451      6977
# 7      56575     54688     97207     70947     26805      8530      3043
# 17     60383     99596    175961    100724     28982      8145      2858
# 39      7565      7321     11668      8558      3370      1162       456
# 22     29228     40728     77893     62936     27932     11179      4664
#
#     CVotes03  CVotes02  CVotes01  ...  Votes3044F  Votes45A  Votes45AM  \
# ...

# %%
df_by_genre['cnt']=1
df_by_g1=df_by_genre.groupby("genre_1").aggregate(np.sum)
df_by_g2=df_by_genre.groupby("genre_2").aggregate(np.sum)
df_by_g3=df_by_genre.groupby("genre_3").aggregate(np.sum)

# %%
df_by_g1
# Out:
#            CVotes10  CVotes09  CVotes08  CVotes07  CVotes06  CVotes05  \
# genre_1
# Action      2928407   3261919   4247693   2662020    986774    364234
# Adventure   1058779   1179818   1560541    966275    365486    136985
# Animation    681562    798227   1153214    722782    251076     83069
# Biography    666831   1088430   1654704    962977    306247    100005
# Comedy       371217    496905    770395    518566    205434     81933
# Crime        383290    690221   1083469    627593    206756     71460
# Drama       1080725   1494053   1827363   1078966    417205    163874
# Mystery      150405    230844    278844    132349     45167     15615
#
#            CVotes04  CVotes03  CVotes02  CVotes01  ...  Votes3044  Votes3044M  \
# genre_1                                            ...
# Action       156150     89483     61975    162426  ...      209.1       208.8
# Adventure     58559     33174     22018     48100  ...       92.7        92.6
# ...

# %%
df_by_g2
# Out:
#            CVotes10  CVotes09  CVotes08  CVotes07  CVotes06  CVotes05  \
# genre_2
# Action       238060    285510    430062    260106     88580     29250
# Adventure   2297820   2548864   3271725   2055600    758009    272735
# Biography    185172    313178    576374    370003    119348     38643
# Comedy       428995    624720    854162    512668    193916     76752
# Crime         19576     40247     85359     64633     24920      8548
# Drama       1923492   2761237   4112363   2492241    853434    300100
# Family        68937     54947    102488     80465     31205     11792
# Fantasy      270616    290831    447307    291071    120920     47215
# History       15757     32840     83322     63800     19183      5178
# Horror        16572     19818     44460     35863     13456      4588
# Music        110404    161864    132656     56007     16577      6031
# Musical       54268     47750     63323     45160     22393     10744
# ...

# %%
df_by_g3
# Out:
#            CVotes10  CVotes09  CVotes08  CVotes07  CVotes06  CVotes05  \
# genre_3
# Adventure    238060    285510    430062    260106     88580     29250
# Comedy       583404    653362    882294    559835    200937     68167
# Crime        171660    236650    250667    129164     46715     18682
# Drama        400221    680085   1167327    748493    258717     88338
# Family        29228     40728     77893     62936     27932     11179
# Fantasy      301836    311392    442460    308676    120911     46269
# History      135504    227547    311209    159262     48678     16055
# Music         74245     71191     64640     38831     17377      8044
# Mystery      274446    443661    654167    375087    128131     44818
# Romance      319534    418790    715954    497486    193588     75675
# Sci-Fi      1975041   2169036   2569011   1517219    546668    200825
# Sport         95717    140282    214806    138600     44470     13821
# ...

# %%
df_add=df_by_g1.add(df_by_g2,fill_value=0)
df_add=df_add.add(df_by_g3,fill_value=0)
df_add
# Out:
#             CVotes10   CVotes09   CVotes08   CVotes07   CVotes06  CVotes05  \
# Action     3166467.0  3547429.0  4677755.0  2922126.0  1075354.0  393484.0
# Adventure  3594659.0  4014192.0  5262328.0  3281981.0  1212075.0  438970.0
# Animation   681562.0   798227.0  1153214.0   722782.0   251076.0   83069.0
# Biography   852003.0  1401608.0  2231078.0  1332980.0   425595.0  138648.0
# Comedy     1383616.0  1774987.0  2506851.0  1591069.0   600287.0  226852.0
# Crime       574526.0   967118.0  1419495.0   821390.0   278391.0   98690.0
# Drama      3404438.0  4935375.0  7107053.0  4319700.0  1529356.0  552312.0
# Family       98165.0    95675.0   180381.0   143401.0    59137.0   22971.0
# Fantasy     572452.0   602223.0   889767.0   599747.0   241831.0   93484.0
# History     151261.0   260387.0   394531.0   223062.0    67861.0   21233.0
# Horror       16572.0    19818.0    44460.0    35863.0    13456.0    4588.0
# ...

# %%
#Extract genres with atleast 10 occurences
genre_top10=df_add[df_add['cnt']>10]
genre_top10
# Out:
#             CVotes10   CVotes09   CVotes08   CVotes07   CVotes06  CVotes05  \
# Action     3166467.0  3547429.0  4677755.0  2922126.0  1075354.0  393484.0
# Adventure  3594659.0  4014192.0  5262328.0  3281981.0  1212075.0  438970.0
# Animation   681562.0   798227.0  1153214.0   722782.0   251076.0   83069.0
# Biography   852003.0  1401608.0  2231078.0  1332980.0   425595.0  138648.0
# Comedy     1383616.0  1774987.0  2506851.0  1591069.0   600287.0  226852.0
# Crime       574526.0   967118.0  1419495.0   821390.0   278391.0   98690.0
# Drama      3404438.0  4935375.0  7107053.0  4319700.0  1529356.0  552312.0
# Romance     549959.0   689492.0  1069280.0   712841.0   281289.0  110901.0
# Sci-Fi     2325284.0  2530855.0  3002994.0  1802098.0   671811.0  254175.0
# Thriller   1081701.0  1465491.0  1993378.0  1175799.0   416046.0  149953.0
#
#            CVotes04  CVotes03  CVotes02  CVotes01  ...  Votes3044  Votes3044M  \
# ...

# %%
#Take the mean for every column by dividing with cnt 
genre_top10.iloc[:,0:-1]=genre_top10.iloc[:,0:-1].divide(genre_top10["cnt"],axis=0)
genre_top10
# Out:
# /home/aditya/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# <ipython-input-68-227e4fce97b0>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genre_top10.iloc[:,0:-1]=genre_top10.iloc[:,0:-1].divide(genre_top10["cnt"],axis=0)
#                 CVotes10       CVotes09       CVotes08       CVotes07  \
# Action     102144.096774  114433.193548  150895.322581   94262.129032
# Adventure   94596.289474  105636.631579  138482.315789   86367.921053
# ...

# %%
# Converting only CVotes to int type
genre_top10[genre_top10.loc[:,"CVotes10":"CVotesnUS"].columns]=genre_top10[genre_top10.loc[:,"CVotes10":"CVotesnUS"].columns].astype(int)

# %%
genre_top10
# Out:
#            CVotes10  CVotes09  CVotes08  CVotes07  CVotes06  CVotes05  \
# Action       102144    114433    150895     94262     34688     12693
# Adventure     94596    105636    138482     86367     31896     11551
# Animation     61960     72566    104837     65707     22825      7551
# Biography     47333     77867    123948     74054     23644      7702
# Comedy        60157     77173    108993     69176     26099      9863
# Crime         52229     87919    129045     74671     25308      8971
# Drama         52375     75928    109339     66456     23528      8497
# Romance       42304     53037     82252     54833     21637      8530
# Sci-Fi       136781    148873    176646    106005     39518     14951
# Thriller      83207    112730    153336     90446     32003     11534
#
#            CVotes04  CVotes03  CVotes02  CVotes01  ...  Votes1829F  Votes3044  \
# Action         5386      3064      2115      5524  ...    8.000000   7.741935
# ...

# %%
#Now let's derive some insights from this data frame. 
#Make a bar chart plotting different genres vs cnt using seaborn
ax=sns.catplot(y=genre_top10['cnt'],x=genre_top10.index,kind='bar',data=genre_top10)
ax.set_xticklabels(rotation=90)

# %%
# 1st set of heat maps for CVotes-related columns
# Males
plt.figure(figsize=(20,10))
plt.subplot(1,2,1)
ax=sns.heatmap(genre_top10[["CVotesU18M","CVotes1829M","CVotes3044M","CVotes45AM"]],annot=True,cmap="YlGnBu")
#Females
plt.subplot(1,2,2)
ax=sns.heatmap(genre_top10[["CVotesU18F","CVotes1829F","CVotes3044F","CVotes45AF"]],annot=True,cmap="YlGnBu")
plt.show()

# %%
# 2nd set of heat maps for Votes-related columns
plt.figure(figsize=(20,10))
plt.subplot(1,2,1)
ax=sns.heatmap(genre_top10[["VotesU18M","Votes1829M","Votes3044M","Votes45AM"]],annot=True,cmap="YlGnBu")
#Females
plt.subplot(1,2,2)
ax=sns.heatmap(genre_top10[["VotesU18F","Votes1829F","Votes3044F","Votes45AF"]],annot=True,cmap="YlGnBu")
plt.show()
